# %% [markdown]
# # 1D Out-of-domain generalization (Figure 2)

# %%
# %pip install torch
# %pip install numpy
# %pip install matplotlib
# %pip install scipy
# %pip install tqdm

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..') #hack
from train import train
from test import test
device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
print('Running on', device)
# Out:
# Running on cuda

# %%
d = 10
N = 40000
n = 40000
M = 10000
mlist = np.array([512, 768, 1152, 1728, 2592, 3888, 5832, 8748, 13122, 19683])
atype = 'const'
lr = 0.001
num_epochs = 10000

# %%
experiments = [
    [dict(train_method='fd',  test_method='fem', Vtype_train='piecewise', Vtype_test='piecewise', alpha_train=None, beta_train=None, alpha_test=None, beta_test=None)],
    [dict(train_method='fem', test_method='fd',  Vtype_train='piecewise', Vtype_test='piecewise', alpha_train=None, beta_train=None, alpha_test=None, beta_test=None)],
    [dict(train_method='fd',  test_method='fem', Vtype_train='piecewise', Vtype_test='lognormal', alpha_train=None, beta_train=None, alpha_test=2,    beta_test=2)],
    [dict(train_method='fd',  test_method='fem', Vtype_train='lognormal', Vtype_test='piecewise', alpha_train=2,    beta_train=2,    alpha_test=None, beta_test=None)],
    [dict(train_method='fd',  test_method='fem', Vtype_train='lognormal', Vtype_test='lognormal', alpha_train=2,    beta_train=2,    alpha_test=2,    beta_test=b) for b in [1, 3, 4]],
    [dict(train_method='fd',  test_method='fem', Vtype_train='lognormal', Vtype_test='lognormal', alpha_train=2,    beta_train=2,    alpha_test=a,    beta_test=2) for a in [1, 3, 4]],
]

all_results = []
for experiment in experiments:
    experiment_results = []
    for cfg in experiment:
        mdl = train(N, n, d, atype, cfg['Vtype_train'], 0.5, cfg['alpha_train'], cfg['beta_train'], cfg['train_method'], lr, num_epochs, print_epoch=False)
        results = test(mdl, M, mlist, d, atype, cfg['Vtype_test'], 0.5, cfg['alpha_test'], cfg['beta_test'], cfg['test_method'], error_type='relative')
        experiment_results.append((results, cfg))
    all_results.append(experiment_results)
# Out:
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:10<00:00, 3852.19it/s]
# Trained model with loss 1.0137377159935568e-07
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:08<00:00, 77.65it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [08:21<00:00, 79.73it/s]
# Trained model with loss 0.0006004425813443959
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [00:02<00:00, 3908.37it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:10<00:00, 3920.31it/s]
# Trained model with loss 1.0137377159935568e-07
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:08<00:00, 77.99it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6457.27it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:05<00:00, 79.98it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6556.34it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:07<00:00, 78.43it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6520.29it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:07<00:00, 78.36it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6455.58it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:08<00:00, 77.98it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6486.54it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:08<00:00, 77.83it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6236.79it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:05<00:00, 79.56it/s]
# (1D) Generating train matrix A of size 40000x10x10
# 100%|██████████| 40000/40000 [00:06<00:00, 6574.05it/s]
# Trained model with loss 9.103010967237424e-08
# (1D) Generating test matrix A of size 10000x10x10
# 100%|██████████| 10000/10000 [02:06<00:00, 79.01it/s]

# %%
y0s = [1e-2, 1.7e-2, 1e-2, 6e-3, 6e-3, 6e-3]
fig, axs = plt.subplots(2, 3, figsize=(12, 6), squeeze=False)
for ax, experiment_results, y0 in zip(axs.T.flat, all_results, y0s):
    for results, cfg in experiment_results:
        print([x - results[-1] for x in results])
        label = f"(α, β) = ({cfg['alpha_test']}, {cfg['beta_test']})"
        ax.plot(mlist[:-3], [x - results[-1] for x in results][:-3], 'o--', label=label)
    ax.plot(mlist[:-3], y0 * (mlist[:-3] / mlist[0])**-1, linestyle = '-', color='black', linewidth=2, alpha=0.5)
    if len(experiment_results) > 1:
        ax.legend()
    ax.loglog()
plt.tight_layout()
plt.show()
# Out:
# [0.011827944850804906, 0.006143391853805857, 0.004140971794387938, 0.0030422740629736378, 0.001765578499177356, 0.0015003372847814944, 0.0008637672590120493, 0.0002513302726891431, 0.000359684508730862, 0.0]
# [0.020873758308030788, 0.012785166985637503, 0.00967560042513882, 0.005534550047178705, 0.0036683620650853066, 0.0025650879215196876, 0.0009585090024759879, 0.00045165076035433294, 5.1885762948344905e-05, 0.0]
# [0.011404225953561886, 0.0056299604483991406, 0.004078225962907078, 0.0029925094267066465, 0.0016951596333729668, 0.0014939335744041382, 0.0008912870148083951, 0.00023982068306538373, 0.0003322717991205981, 0.0]
# [0.00919655467306757, 0.003521779334776154, 0.002845743122950384, 0.0018782437938311691, 0.0011050976534774382, 0.0010585648868098874, 0.0004717720326428143, -3.6799551863198054e-05, 0.0001667535248681684, 0.0]
# [0.008887614060330895, 0.0027118208491365703, 0.0027040895706371693, 0.0017079532920503127, 0.0011750344671183077, 0.0011756937234245202, 0.0006610542778902051, -9.499284047653767e-05, 0.00017350427329942963, 0.0]
# [0.008746783957652604, 0.0030954873107881253, 0.002786187867642731, 0.0018890553172964397, 0.000960852978185156, 0.0010506574361222043, 0.0004767479720274581, -2.48071894639601e-05, 0.0001437965761822424, 0.0]
# [0.008740886649660884, 0.0031241342119544546, 0.002791562143727111, 0.0018958857873694335, 0.0009511962499930693, 0.0010404659146772133, 0.0004633752349409992, -2.177012258641753e-05, 0.0001421139007948824, 0.0]
# [0.008772039963463096, 0.0029873788384687794, 0.0027634967793677134, 0.001858506174710839, 0.0010034962844130968, 0.0010881116928243006, 0.0005284975293816663, -3.7546191976045584e-05, 0.000151883141693121, 0.0]
# [0.008767887130784247, 0.0030092945576889463, 0.0027690876191382996, 0.0018639864177757426, 0.0009948221655217138, 0.0010809615756312008, 0.000517200686492858, -3.4965680213550066e-05, 0.0001497575227203951, 0.0]
# [0.008766195441182512, 0.0030180039483067578, 0.0027712347785198155, 0.0018661311257531787, 0.000991570015408505, 0.0010782185403311884, 0.0005127868205833108, -3.394290499780794e-05, 0.0001490087457325373, 0.0]
